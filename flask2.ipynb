# %% [markdown]
# Q1.
# GET:
#
# Used to retrieve data from the server.
# Data is included in the URL as query parameters (e.g., http://example.com/search?q=flask).
#
# POST:
#
# Used to submit data to the server to create or update resources.
# Data is sent in the request body, not visible in the URL.

# %% [markdown]
# Q2..
# The request object in Flask represents the incoming HTTP request from the client. It provides access to:
#
# Request Method: GET, POST, PUT, DELETE, etc.
# Request URL: The complete requested URL

# %% [markdown]
# Q3..
# It's used for:
#
# Redirecting after form submissions: To avoid page reloads or display success messages on a new page.
# Moving users to different pages based on actions or conditions: To control navigation flow within the application.
# Implementing authentication and authorization: To redirect users to login pages or protected areas.

# %% [markdown]
# Q4.
#
# Templates in Flask are HTML files that can contain dynamic content generated by Python code. They allow you to create structured and reusable layouts for your web pages.
#
# Fetches the template file from the templates folder (by default).
# Passes data to the template as variables using a dictionary.
# Processes Jinja2 template syntax to combine static HTML with dynamic Python output.

# %%
Q5..
